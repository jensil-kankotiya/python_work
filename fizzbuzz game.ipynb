# %%
for l in range (0,100):
    if l % 3 and l % 5 == 0:
        print('FizzBuzz')
    elif l % 3  == 0:
        print('Fizz')
    elif l % 5 == 0:
        print('Buzz')
    else:
        print(number)
# Out:
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz
# FizzBuzz
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# 5
# Fizz
# 5
# FizzBuzz
# Fizz
# 5
# 5
# Fizz

# %%
leap_year = int(input('Enter the year please.: '))
if leap_year % 400 == 0:
    print("Congratulations, it's leap year.")
else:
    print('It\'s not a leap year, dear.')
# Out:
# Enter the year please.: 23
# It's not a leap year, dear.
